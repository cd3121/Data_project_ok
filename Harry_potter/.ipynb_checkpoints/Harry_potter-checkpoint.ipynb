# %%
import requests as rq
import time
import random
import lxml
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
response = rq.get('http://www.hogwartsishere.com/library/book/7391/')
doc = BeautifulSoup(response.text)

# %%
episodes = []
results = doc.find_all('li', class_="hover-white")
for result in results:
    episode = result.find('a')['href']
    episodes.append(episode)
episodes
# Out:
# ['/library/book/7391/chapter/1/',
#  '/library/book/7391/chapter/2/',
#  '/library/book/7391/chapter/3/',
#  '/library/book/7391/chapter/4/',
#  '/library/book/7391/chapter/5/',
#  '/library/book/7391/chapter/6/',
#  '/library/book/7391/chapter/7/',
#  '/library/book/7391/chapter/8/']

# %%
full_urls = []
for url in episodes:
    url = f"http://www.hogwartsishere.com/{url}"
    full_urls.append(url)
full_urls
# Out:
# ['http://www.hogwartsishere.com//library/book/7391/chapter/1/',
#  'http://www.hogwartsishere.com//library/book/7391/chapter/2/',
#  'http://www.hogwartsishere.com//library/book/7391/chapter/3/',
#  'http://www.hogwartsishere.com//library/book/7391/chapter/4/',
#  'http://www.hogwartsishere.com//library/book/7391/chapter/5/',
#  'http://www.hogwartsishere.com//library/book/7391/chapter/6/',
#  'http://www.hogwartsishere.com//library/book/7391/chapter/7/',
#  'http://www.hogwartsishere.com//library/book/7391/chapter/8/']

# %%
urltest = "http://www.hogwartsishere.com//library/book/7391/chapter/1/"
response = rq.get(urltest)
doc = BeautifulSoup(response.content)
line_text = []
scripts = doc.find('div', class_="font-size-16 roboto")

print(scripts.content)

#for script in scripts:
#    line_text.append(script.contents)
#    print(line_text)
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-0ce6ba04e0b7> in <module>
# ----> 1 re.findall(r'\S+|\n',s)
#
# NameError: name 's' is not defined

# %%
clean_lines = []
for line in line_text:
    a = re.sub('(<br/>)', '\b', str(line))
    b = re.sub('(\n)', '', a)
    clean_lines.append(b)
clean_lines
# Out:
# ['[\'\\n                            \\tScene:\', \x08, \x08, \'A neighbourhood on a street called Privet Drive. An owl, sitting on the street sign flies off to reveal a mysterious appearing old man walking through a forest near the street. He stops at the start of the street and takes out a mechanical device and zaps all the light out of the lampposts. He puts away the device and a cat meows. The man, ALBUS DUMBLEDORE, looks down at the cat, which is a tabby and is sitting on a brick ledge.\', \x08, \x08, \' \', \x08, \x08, \'Dumbledore: I should have known that you would be here...Professor McGonagall.\', \x08, \x08, \' \', \x08, \x08, \'The cat meows, sniffs out and the camera pans back to a wall. The cats shadow is seen progressing into a human. There are footsteps and MINERVA MCGONAGALL is revealed.\', \x08, \x08, \' \', \x08, \x08, \'McGonagall: Good evening, Professor Dumbledore. Are the rumours true, Albus?\', \x08, \x08, \' \', \x08, \x08, "Dumbledore: I\'m afraid so, Professor. The good, and the bad.", \x08, \x08, \'McGonagall: And the boy?\', \x08, \x08, \'Dumbledore: Hagrid is bringing him.\', \x08, \x08, \'McGonagall: Do you think it wise to trust Hagrid with something as important as this?\', \x08, \x08, \'Albus: Ah, Professor, I would trust Hagrid with my life.\', \x08, \x08, \' \', \x08, \x08, \'There is a motor sound, and the two professors look up to see a flying motorcycle coming down from the air. It skids on the street and halts. A large man, RUBEUS HAGRID, takes off his goggles.\', \x08, \x08, \' \', \x08, \x08, \'Hagrid: Professor Dumbledore, Sir. Professor McGonagall.\', \x08, \x08, \'Dumbledore: No problems, I trust, Hagrid?\', \x08, \x08, \'Hagrid: No, sir. Little tyke fell asleep just as we were flying over Bristol. Heh. Try not to wake him. There you go.\', \x08, \x08, \' \', \x08, \x08, \'Hagrid hands a baby in a blanket over to Dumbledore.\', \x08, \x08, \' \', \x08, \x08, "McGonagall: Albus, do you really think its safe, leaving him with these people? I\'ve been watching them all day. They\'re the worst sort of Muggles imaginable. They really are", \x08, \x08, \'Dumbledore: The only family he has.\', \x08, \x08, \' \', \x08, \x08, \'They stop outside a house.\', \x08, \x08, \' \', \x08, \x08, "McGonagall: This boy will be famous. There wont be a child in our world who doesn\'t know his name.", \x08, \x08, "Dumbledore: Exactly. He\'s better off growing up away from all that. Until he is ready.", \x08, \x08, \' \', \x08, \x08, \'Hagrid coughs and sniffles, he is crying. He clears his throat.\', \x08, \x08, \' \', \x08, \x08, "Dumbledore: There, there, Hagrid. It\'s not really good-bye, after all.", \x08, \x08, \' \', \x08, \x08, \'Hagrid nods. Dumbledore takes a letter and places it on the baby, who is now at the foot of the door. The baby has a visible lightning-bolt shaped scar on his forehead.\', \x08, \x08, \' \', \x08, \x08, \'Dumbledore: Good luck...Harry Potter.\', \x08, \x08, \' \', \x08, \x08, \'The camera pans into the scar and the opening title shows:\', \x08, \x08, "HARRY POTTER AND THE PHILOSOPHER\'S STONE", \x08, \x08, \x08, "Almost ten years after the: DURSLEY\'s home. The camera pans on a sleeping boy, almost eleven, with a lightning-bolt shaped scar on his forehead.", \x08, \x08, \'There is a click, and knocking. Outside, a tall woman, PETUNIA DURSLEY, raps the door.\', \x08, \x08, \' \', \x08, \x08, \'Petunia: Up. Get up. {Knocks} {sighs} Now! {Smacks door of closet which is the boys bedroom}\', \x08, \x08, \' \', \x08, \x08, \'A large, tubby boy, DUDLEY DURSLEY, suddenly comes running down the stairs above the closet. He stops half-way down and goes back, jumping on the staircase.\', \x08, \x08, \' \', \x08, \x08, "Dudley: Wake up, cousin! We\'re going to the zoo!", \x08, \x08, \' \', \x08, \x08, \'Dudley laughs, comes down the stairs and runs for the kitchen. The boy, HARRY POTTER, tries to come out of the closet, but is pushed back in by Dudley.\', \x08, \x08, \' \', \x08, \x08, ...

# %%
clean_lines_ok = []
for line in clean_lines.iterrows():
    if str(line) != '\b':
        clean_lines_ok.append(line)
clean_lines_ok
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-59c56ba539db> in <module>
#       1 clean_lines_ok = []
# ----> 2 for line in clean_lines.iterrows():
#       3     if str(line) != '\b':
#       4         clean_lines_ok.append(line)
#       5 clean_lines_ok
#
# AttributeError: 'list' object has no attribute 'iterrows'

# %%
regex code = (<br/>\w.*?<br/>)
